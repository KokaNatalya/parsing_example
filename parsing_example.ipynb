# %% [markdown]
# # Парсинг сайта

# %% [markdown]
# **Цель** - создать таблицу с данными о товарах интернет-магазина, представленными на сайте, и отработать технику парсинга сайтов.
#
# Для парсинга использовался сайт интернет-магазина текстиля для дома TAG tekstil https://tagtekstil.com.ua/. (найден на сайте со списком сайтов разрешенных для парсинга).

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
from urllib.parse import urljoin

# %%
# путь к сайту
root = 'https://tagtekstil.com.ua/'

# %%
r=requests.get(root)
r.ok
# Out:
# True

# %%
soup=BeautifulSoup(r.text)

# %% [markdown]
# вызовем HTML со страницы с каталогом

# %%
soup.select('ul.VMmenu li')
# Out:
# [<li class="VmClose">
#  <div>
#  <a href="/postelnoe-tm-tag">ПОСТЕЛЬНОЕ БЕЛЬЕ ТМ TAG</a> <span class="VmArrowdown"> </span>
#  </div>
#  <ul class="menu">
#  <li>
#  <div><a href="/postelnoe-tm-tag/polutornyi">1.5-спальные</a></div>
#  </li>
#  <li>
#  <div><a href="/postelnoe-tm-tag/2-sp">2-спальные</a></div>
#  </li>
#  <li>
#  <div><a href="/postelnoe-tm-tag/evro">евро</a></div>
#  </li>
#  <li>
#  <div><a href="/postelnoe-tm-tag/евро-maxi">Евро maxi</a></div>
#  </li>
#  <li>
#  <div><a href="/postelnoe-tm-tag/semeinie">семейные</a></div>
#  </li>
#  </ul>
#  </li>,
#  <li>
#  <div><a href="/postelnoe-tm-tag/polutornyi">1.5-спальные</a></div>
#  </li>,
#  <li>
#  <div><a href="/postelnoe-tm-tag/2-sp">2-спальные</a></div>
#  </li>,
#  <li>
#  <div><a href="/postelnoe-tm-tag/evro">евро</a></div>
#  </li>,
#  <li>
#  <div><a href="/postelnoe-tm-tag/евро-maxi">Евро maxi</a></div>
#  </li>,
#  <li>
#  <div><a href="/postelnoe-tm-tag/semeinie">семейные</a></div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/скидка">ТОВАРЫ СО СКИДКАМИ</a> </div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/tm-tag-detskie2013-08-19-12-06-59530652635">ПОСТЕЛЬНОЕ БЕЛЬЕ И ТОВАРЫ ДЛЯ ДЕТЕЙ</a> <span class="VmArrowdown"> </span>
#  </div>
#  <ul class="menu">
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/1-5-spalnye">1.5-спальные</a></div>
#  </li>
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/1-5-spalnye-160kh220">1.5-спальные 160х220</a></div>
#  </li>
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/v-krovatku">В кроватку</a></div>
#  </li>
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/в-кроватку-на-резинке">Комплекты в кроватку с простынью на резинке</a></div>
#  </li>
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/пледы-детские">Пледы детские</a></div>
#  </li>
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/подушки-и-одеяла">Подушки и одеяла</a></div>
#  </li>
#  </ul>
#  </li>,
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/1-5-spalnye">1.5-спальные</a></div>
#  </li>,
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/1-5-spalnye-160kh220">1.5-спальные 160х220</a></div>
#  </li>,
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/v-krovatku">В кроватку</a></div>
#  </li>,
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/в-кроватку-на-резинке">Комплекты в кроватку с простынью на резинке</a></div>
#  </li>,
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/пледы-детские">Пледы детские</a></div>
#  </li>,
#  <li>
#  <div><a href="/tm-tag-detskie2013-08-19-12-06-59530652635/подушки-и-одеяла">Подушки и одеяла</a></div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/пледы-тм-tag">Пледы ТМ TAG</a> <span class="VmArrowdown"> </span>
#  </div>
#  <ul class="menu">
#  <li>
#  <div><a href="/пледы-тм-tag/160х220">160х220</a></div>
#  </li>
#  <li>
#  <div><a href="/пледы-тм-tag/200х220">200х220</a></div>
#  </li>
#  </ul>
#  </li>,
#  <li>
#  <div><a href="/пледы-тм-tag/160х220">160х220</a></div>
#  </li>,
#  <li>
#  <div><a href="/пледы-тм-tag/200х220">200х220</a></div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/стеганные-покрывала-одеяля">Стеганные покрывала-одеяла</a> </div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/polotentsa">Полотенца</a> <span class="VmArrowdown"> </span>
#  </div>
#  <ul class="menu">
#  <li>
#  <div><a href="/polotentsa/50-90-ot-1-ed">50*90 от 1 ед.</a></div>
#  </li>
#  <li>
#  <div><a href="/polotentsa/70-140-ot-1-ed">70*140 от 1 ед.</a></div>
#  </li>
#  <li>
#  <div><a href="/polotentsa/40-70-от-1-ед">40*70 от 1 ед.</a></div>
#  </li>
#  <li>
#  <div><a href="/polotentsa/наборы-полотенец">Наборы полотенец</a></div>
#  </li>
#  <li>
#  <div><a href="/polotentsa/полотенца-для-ног">Полотенца для ног</a></div>
#  </li>
#  <li>
#  <div><a href="/polotentsa/сауна">Сауна</a></div>
#  </li>
#  </ul>
#  </li>,
#  <li>
#  <div><a href="/polotentsa/50-90-ot-1-ed">50*90 от 1 ед.</a></div>
#  </li>,
#  <li>
#  <div><a href="/polotentsa/70-140-ot-1-ed">70*140 от 1 ед.</a></div>
#  </li>,
#  <li>
#  <div><a href="/polotentsa/40-70-от-1-ед">40*70 от 1 ед.</a></div>
#  </li>,
#  <li>
#  <div><a href="/polotentsa/наборы-полотенец">Наборы полотенец</a></div>
#  </li>,
#  <li>
#  <div><a href="/polotentsa/полотенца-для-ног">Полотенца для ног</a></div>
#  </li>,
#  <li>
#  <div><a href="/polotentsa/сауна">Сауна</a></div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/пляжные-полотенца">Пляжные полотенца</a> </div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/кухонные-полотенца">Кухонные полотенца</a> </div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/простыни-на-резинке">Простыни на резинке</a> <span class="VmArrowdown"> </span>
#  </div>
#  <ul class="menu">
#  <li>
#  <div><a href="/простыни-на-резинке/razmer-160kh200kh20">Размер 160х200х20</a></div>
#  </li>
#  <li>
#  <div><a href="/простыни-на-резинке/razmer-180kh200kh20">Размер 180х200х20</a></div>
#  </li>
#  </ul>
#  </li>,
#  <li>
#  <div><a href="/простыни-на-резинке/razmer-160kh200kh20">Размер 160х200х20</a></div>
#  </li>,
#  <li>
#  <div><a href="/простыни-на-резинке/razmer-180kh200kh20">Размер 180х200х20</a></div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/наволочки">Наволочки</a> <span class="VmArrowdown"> </span>
#  </div>
#  <ul class="menu">
#  <li>
#  <div><a href="/наволочки/наволочки-50х70-см">Наволочки 50х70 см</a></div>
#  </li>
#  <li>
#  <div><a href="/наволочки/наволочки-70х70-см">Наволочки 70х70 см</a></div>
#  </li>
#  </ul>
#  </li>,
#  <li>
#  <div><a href="/наволочки/наволочки-50х70-см">Наволочки 50х70 см</a></div>
#  </li>,
#  <li>
#  <div><a href="/наволочки/наволочки-70х70-см">Наволочки 70х70 см</a></div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/подушки-тм-tag">Подушки</a> </div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/одеяла-тм-tag">Одеяла</a> </div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/наматрасники">Наматрасники</a> </div>
#  </li>,
#  <li class="VmClose">
#  <div>
#  <a href="/ортопедические-матрасы">Ортопедические матрасы</a> </div>
#  </li>]

# %% [markdown]
# создадим таблицу с товарными категориями и ссылками на них

# %%
# функция, которая делает таблицу
def parsing_cathegory(x):
    return {
        'link': f"https://tagtekstil.com.ua/{x.select_one('a')['href']}",
        'type': x.select_one('a').text
    }

# %%
cathegories = pd.DataFrame([parsing_cathegory(x) for x in soup.select('ul.VMmenu li')])
cathegories
# Out:
#                                                  link  \
# 0         https://tagtekstil.com.ua//postelnoe-tm-tag
# 1   https://tagtekstil.com.ua//postelnoe-tm-tag/po...
# 2    https://tagtekstil.com.ua//postelnoe-tm-tag/2-sp
# 3    https://tagtekstil.com.ua//postelnoe-tm-tag/evro
# 4   https://tagtekstil.com.ua//postelnoe-tm-tag/ев...
# 5   https://tagtekstil.com.ua//postelnoe-tm-tag/se...
# 6                   https://tagtekstil.com.ua//скидка
# 7   https://tagtekstil.com.ua//tm-tag-detskie2013-...
# 8   https://tagtekstil.com.ua//tm-tag-detskie2013-...
# 9   https://tagtekstil.com.ua//tm-tag-detskie2013-...
# 10  https://tagtekstil.com.ua//tm-tag-detskie2013-...
# 11  https://tagtekstil.com.ua//tm-tag-detskie2013-...
# 12  https://tagtekstil.com.ua//tm-tag-detskie2013-...
# 13  https://tagtekstil.com.ua//tm-tag-detskie2013-...
# 14            https://tagtekstil.com.ua//пледы-тм-tag
# 15    https://tagtekstil.com.ua//пледы-тм-tag/160х220
# 16    https://tagtekstil.com.ua//пледы-тм-tag/200х220
# 17  https://tagtekstil.com.ua//стеганные-покрывала...
# 18              https://tagtekstil.com.ua//polotentsa
# 19  https://tagtekstil.com.ua//polotentsa/50-90-ot...
# 20  https://tagtekstil.com.ua//polotentsa/70-140-o...
# 21  https://tagtekstil.com.ua//polotentsa/40-70-от...
# 22  https://tagtekstil.com.ua//polotentsa/наборы-п...
# 23  https://tagtekstil.com.ua//polotentsa/полотенц...
# 24        https://tagtekstil.com.ua//polotentsa/сауна
# 25       https://tagtekstil.com.ua//пляжные-полотенца
# 26      https://tagtekstil.com.ua//кухонные-полотенца
# 27     https://tagtekstil.com.ua//простыни-на-резинке
# 28  https://tagtekstil.com.ua//простыни-на-резинке...
# 29  https://tagtekstil.com.ua//простыни-на-резинке...
# 30               https://tagtekstil.com.ua//наволочки
# 31  https://tagtekstil.com.ua//наволочки/наволочки...
# 32  https://tagtekstil.com.ua//наволочки/наволочки...
# 33          https://tagtekstil.com.ua//подушки-тм-tag
# 34           https://tagtekstil.com.ua//одеяла-тм-tag
# 35            https://tagtekstil.com.ua//наматрасники
# 36  https://tagtekstil.com.ua//ортопедические-матрасы
#
#                                            type
# 0                       ПОСТЕЛЬНОЕ БЕЛЬЕ ТМ TAG
# 1                                  1.5-спальные
# 2                                    2-спальные
# 3                                          евро
# 4                                     Евро maxi
# 5                                      семейные
# 6                            ТОВАРЫ СО СКИДКАМИ
# 7           ПОСТЕЛЬНОЕ БЕЛЬЕ И ТОВАРЫ ДЛЯ ДЕТЕЙ
# 8                                  1.5-спальные
# 9                          1.5-спальные 160х220
# 10                                   В кроватку
# 11  Комплекты в кроватку с простынью на резинке
# 12                                Пледы детские
# 13                             Подушки и одеяла
# 14                                 Пледы ТМ TAG
# 15                                      160х220
# 16                                      200х220
# 17                   Стеганные покрывала-одеяла
# 18                                    Полотенца
# 19                               50*90 от 1 ед.
# 20                              70*140 от 1 ед.
# 21                               40*70 от 1 ед.
# 22                             Наборы полотенец
# 23                            Полотенца для ног
# 24                                        Сауна
# 25                            Пляжные полотенца
# 26                           Кухонные полотенца
# 27                          Простыни на резинке
# 28                            Размер 160х200х20
# 29                            Размер 180х200х20
# 30                                    Наволочки
# 31                           Наволочки 50х70 см
# 32                           Наволочки 70х70 см
# 33                                      Подушки
# 34                                       Одеяла
# 35                                 Наматрасники
# 36                       Ортопедические матрасы

# %% [markdown]
# сделаем таблицу содержащую наименование товара, ссылку на фото товара и тип категории. на сайте не указаны цены, поэтому не можем создать столбец с ценами

# %%
data=[]

for i in cathegories.index:
    types = cathegories.loc[i, 'type']
    url = cathegories.loc[i, 'link']
    
    r=requests.get(cathegories.loc[i, 'link'])
    soup = BeautifulSoup(r.text)
    products = soup.select('div.spacer')
    
    for product in products:
        title = product.select_one('h2 a').text.strip()
        img=urljoin(url, product.select_one('img')['src'])
        
        data.append({
            'title': title,
            'img':img,
            'type':types
        })
df=pd.DataFrame(data)[45:].reset_index(drop=True)
display(df.sample(10))
# Out:
#                                            title  \
# 502  Полотенце 100х150 Calm tones цвет: молочный
# 152             Комплект постельного белья R8657
# 404                    Стеганное покрывало Гонки
# 281             Плед велсофт (микрофибра) VL-030
# 133         Комплект постельного белья Lol dolls
# 727     Наматрасник "Аква стоп" с бортами 60х120
# 312            Плед велсофт (микрофибра) ALM1904
# 515            Набор полотенец 30*30 (6шт) Белые
# 498   Полотенце 100х150 Calm tones цвет: голубой
# 658                     Одеяло "Eco-cotton" евро
#
#                                                    img  \
# 502  https://tagtekstil.com.ua/images/stories/virtu...
# 152  https://tagtekstil.com.ua/images/stories/virtu...
# 404  https://tagtekstil.com.ua/images/stories/virtu...
# 281  https://tagtekstil.com.ua/images/stories/virtu...
# 133  https://tagtekstil.com.ua/images/stories/virtu...
# 727  https://tagtekstil.com.ua/images/stories/virtu...
# 312  https://tagtekstil.com.ua/images/stories/virtu...
# 515  https://tagtekstil.com.ua/images/stories/virtu...
# 498  https://tagtekstil.com.ua/images/stories/virtu...
# 658  https://tagtekstil.com.ua/images/stories/virtu...
#
#                            type
# 502                       Сауна
# 152        1.5-спальные 160х220
# 404  Стеганные покрывала-одеяла
# 281                     160х220
# 133        1.5-спальные 160х220
# 727                Наматрасники
# 312                     200х220
# 515          Кухонные полотенца
# 498                       Сауна
# 658                      Одеяла

# %%
df['type'].value_counts()
# Out:
# Одеяла                                         83
# 160х220                                        78
# 200х220                                        69
# ТОВАРЫ СО СКИДКАМИ                             63
# 1.5-спальные                                   61
# 70*140 от 1 ед.                                53
# 1.5-спальные 160х220                           51
# Подушки                                        44
# Наматрасники                                   30
# Стеганные покрывала-одеяла                     29
# Наволочки 70х70 см                             26
# Пледы детские                                  21
# 50*90 от 1 ед.                                 19
# Подушки и одеяла                               17
# Кухонные полотенца                             15
# Сауна                                          15
# Размер 160х200х20                              12
# Размер 180х200х20                              12
# Наволочки                                      10
# Ортопедические матрасы                          9
# 40*70 от 1 ед.                                  7
# ПОСТЕЛЬНОЕ БЕЛЬЕ И ТОВАРЫ ДЛЯ ДЕТЕЙ             6
# Полотенца                                       6
# Наволочки 50х70 см                              5
# Комплекты в кроватку с простынью на резинке     5
# В кроватку                                      5
# Наборы полотенец                                4
# Простыни на резинке                             2
# Пледы ТМ TAG                                    2
# Полотенца для ног                               1
# Пляжные полотенца                               1
# Name: type, dtype: int64

# %% [markdown]
# - не по всем категориям понятно к какой категории относится товар (дан только размер). добавим названия категорий в такие строки;
# - некоторые категории написаны большими буквами, приведем к строчным.

# %%
# функция меняющая категорию в зависимости от названия предыдущей категории
def change_cathegory(df, col, old_cath, new_cath):
    for i in old_cath: 
        df.loc[df[col]==i]=(f'{new_cath} {i}')

# %%
df['type']=df['type'].str.lower() #перевод к строчным буквам

cath=['70*140 от 1 ед.', '50*90 от 1 ед.', '40*70 от 1 ед.']
sheet=['размер 160х200х20', 'размер 180х200х20']      # категории которые надо дополнить
pled=['160х220', '200х220']
complect=['1.5-спальные', '1.5-спальные 160х220']

change_cathegory(df, 'type', cath, 'полотенце')
change_cathegory(df, 'type', sheet, 'простыня')
change_cathegory(df, 'type', pled, 'плед')
change_cathegory(df, 'type', complect, 'комплекты белья')

# %%
df['type'].value_counts()
# Out:
# одеяла                                         83
# плед 160х220                                   78
# плед 200х220                                   69
# товары со скидками                             63
# комплекты белья 1.5-спальные                   61
# полотенце 70*140 от 1 ед.                      53
# комплекты белья 1.5-спальные 160х220           51
# подушки                                        44
# наматрасники                                   30
# стеганные покрывала-одеяла                     29
# наволочки 70х70 см                             26
# пледы детские                                  21
# полотенце 50*90 от 1 ед.                       19
# подушки и одеяла                               17
# сауна                                          15
# кухонные полотенца                             15
# простыня размер 160х200х20                     12
# простыня размер 180х200х20                     12
# наволочки                                      10
# ортопедические матрасы                          9
# полотенце 40*70 от 1 ед.                        7
# постельное белье и товары для детей             6
# полотенца                                       6
# в кроватку                                      5
# наволочки 50х70 см                              5
# комплекты в кроватку с простынью на резинке     5
# наборы полотенец                                4
# простыни на резинке                             2
# пледы тм tag                                    2
# пляжные полотенца                               1
# полотенца для ног                               1
# Name: type, dtype: int64

# %%
df
# Out:
#                                     title  \
# 0    Комплект постельного белья R4047grey
# 1        Комплект постельного белья R4121
# 2         Комплект постельного белья S446
# 3         Комплект постельного белья S476
# 4         Комплект постельного белья S476
# ..                                    ...
# 756              Матрас топпер "Istanbul"
# 757    Ортопедический матрас "Alexandria"
# 758         Ортопедический матрас "Genoa"
# 759     Ортопедический матрас "Liverpool"
# 760      Ортопедический матрас "New York"
#
#                                                    img                    type
# 0    https://tagtekstil.com.ua/images/stories/virtu...      товары со скидками
# 1    https://tagtekstil.com.ua/images/stories/virtu...      товары со скидками
# 2    https://tagtekstil.com.ua/images/stories/virtu...      товары со скидками
# 3    https://tagtekstil.com.ua/images/stories/virtu...      товары со скидками
# 4    https://tagtekstil.com.ua/images/stories/virtu...      товары со скидками
# ..                                                 ...                     ...
# 756  https://tagtekstil.com.ua/images/stories/virtu...  ортопедические матрасы
# 757  https://tagtekstil.com.ua/images/stories/virtu...  ортопедические матрасы
# 758  https://tagtekstil.com.ua/images/stories/virtu...  ортопедические матрасы
# 759  https://tagtekstil.com.ua/images/stories/virtu...  ортопедические матрасы
# 760  https://tagtekstil.com.ua/images/stories/virtu...  ортопедические матрасы
#
# [761 rows x 3 columns]

# %% [markdown]
# ________________________________________________________________________________
# ***таблица готова!***
